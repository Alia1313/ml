# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_classification

# %%
iris = load_iris()
X = iris.data[:, 2:]
y = iris.target

# %% [markdown]
# Решим задачу многоклассовой логистической регрессии

# %%
model = LogisticRegression(max_iter=200, random_state=0)
model.fit(X, y)
# Out:
# LogisticRegression(max_iter=200, random_state=0)

# %% [markdown]
# Отрисуем полученное решение на плоскости 'petal length  - petal width'

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                     np.arange(y_min, y_max, 0.02))

Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.figure(figsize=(10, 6))
plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.Paired)
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolor='k', cmap=plt.cm.Paired)
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.colorbar(ticks=[0, 1, 2], label='Класс')
plt.show()
